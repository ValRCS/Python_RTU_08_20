# %%
# Attendance Calc

# %%
import pandas as pd

# %%
d1 = pd.read_excel('g1.xlsx')
d1.head()
# Out:
#                  Persona                            email 17.08 19.08 24.08  \
# 0     ALEKSEJS ANČEVSKIS         alex.ancevskis@gmail.com    10    10     8
# 1  ARTJOMS NURMUHAMATOVS  artjoms.nurmuhamatovs@gmail.com    10    10    10
# 2        ROMĀNS BUTAKOVS           butakovroman@gmail.com    10     8    10
# 3           DĀVIS CIBULS           cibuls.davis@gmail.com    10     8     8
# 4     DMITRIJS GŅEVAŠEVS       dmitry.gnevashev@gmail.com     8    10    10
#
#   26.08 31.08 2.08 Unnamed: 8
# 0    10    10   10        NaN
# 1    10     8   10        NaN
# 2    10     8   10        NaN
# 3     6     -    -        NaN
# 4    10     8   10        NaN

# %%
d2 = pd.read_excel('gr14.xlsx')
d2.head()
# Out:
#      Vārds   Uzvārds                      email  18.08 20.08 25.08 27.08 1.09  \
# 0    AGRIS  AURMANIS   agris.aurmanis@gmail.com     10    10    10    10   10
# 1   ANDRIS   BĒRZIŅŠ       job.andris@gmail.com     10    10    10    10   10
# 2  Austris   Birkāns  Austris.birkans@gmail.com     10    10    10    10   10
# 3  DANIELS     BROKS     daniels_broks@inbox.lv      8    10    10     6    6
# 4  VITAUTS  BUDREIKA         vitauts@klints.com     10    10    10    10   10
#
#   3.09
# 0   10
# 1   10
# 2    -
# 3   10
# 4   10

# %%
d = pd.read_excel('PythonGrades.xlsx')
d.head()
# Out:
#   First name       Surname  ID number Institution  Department  \
# 0      ĒRIKS         ĀBELE        NaN         NaN         NaN
# 1   NATĀLIJA  ALEKSANDROVA        NaN         NaN         NaN
# 2    SARMĪTE        ALEKSE        NaN         NaN         NaN
# 3      ILONA    AĻEKSEJEVA        NaN         NaN         NaN
# 4       RŪTA      ALENČIKA        NaN         NaN         NaN
#
#                             email Quiz: Ievads Programmēšanā - Quiz (Real)  \
# 0            eriks.abele@inbox.lv                                        8
# 1  natalija.aleksandrova@inbox.lv                                       10
# 2        sarmite.alekse@gmail.com                                       10
# 3               slonija@gmail.com                                       10
# 4         ruta.alencika@gmail.com                                        8
#
#   Quiz: Python Mainīgie - Quiz (Real)  \
# 0                                  10
# 1                                  10
# ...

# %%
d.describe(include='O').T
# Out:
#                                                    count unique  \
# First name                                           265    164
# Surname                                              265    254
# Institution                                            1      1
# email                                                265    265
# Quiz: Ievads Programmēšanā - Quiz (Real)             265      4
# Quiz: Python Mainīgie - Quiz (Real)                  265      5
# Quiz: Python - Quiz salidzināšana, if/elif/else...   265      6
# Quiz: Python - Cikli - Quiz (Real)                   265      6
# Quiz: String Quiz Pārbaude (Real)                    265      5
# Quiz: Python Lists Quiz (Real)                       265      4
# Quiz: Funkcijas - Tests (Quiz) (Real)                265      3
# Quiz: Dictionary Quiz (Real)                         265      4
# Quiz: Sets and Tuples - QUIZ (Real)                  265      7
# Quiz: Classes - QUIZ (Real)                          265      5
# ...

# %%
ge1 = list(d1.email)
ge1
# Out:
# ['alex.ancevskis@gmail.com',
#  'artjoms.nurmuhamatovs@gmail.com',
#  'butakovroman@gmail.com',
#  'cibuls.davis@gmail.com',
#  'dmitry.gnevashev@gmail.com',
#  'dzerveaa@gmail.com',
#  'Edgars.Viksna@latloto.lv',
#  'fricbergs@gmail.com',
#  'frolova_anna@inbox.lv',
#  'gatis.patmalnieks@gmail.com',
#  'gbrakovskis@gmail.com',
#  'ija.sorokina@inbox.lv',
#  'info@pakalpojums.lv',
#  'jurkins@inbox.lv',
#  'kaspars.purinss@gmail.com',
#  'katrina.kukuma@gmail.com',
#  'Ljusja@tvnet.lv',
#  'merita.baikovska@gmail.com',
#  'miksru@gmail.com',
#  'Nauris.Krumins@gmail.com',
#  'ozolins.davis@icloud.com',
#  'raivo.bauze@gmail.com',
#  'reno.jekabsons@gmail.com',
#  'Roberts.Auzins@fm.gov.lv',
#  'sautinsjanis@gmail.com',
#  'semjonovsj@inbox.lv',
#  'skmara2@inbox.lv',
#  'soulhunter@inbox.lv',
#  'Swetikd@inbox.lv',
#  'toms.mikelsons@gmail.com']

# %%
gr3 = d[d.email.isin(ge1)]
gr3.shape
# Out:
# (30, 25)

# %%
gr3.head()
# Out:
#    First name     Surname  ID number Institution  Department  \
# 7    ALEKSEJS   ANČEVSKIS        NaN         NaN         NaN
# 13    Roberts      Auziņš        NaN         NaN         NaN
# 16     MERITA   BAIKOVSKA        NaN         NaN         NaN
# 20      RAIVO       BAUZE        NaN         NaN         NaN
# 33      GINTS  BRAKOVSKIS        NaN         NaN         NaN
#
#                          email Quiz: Ievads Programmēšanā - Quiz (Real)  \
# 7     alex.ancevskis@gmail.com                                       10
# 13    Roberts.Auzins@fm.gov.lv                                       10
# 16  merita.baikovska@gmail.com                                        8
# 20       raivo.bauze@gmail.com                                       10
# 33       gbrakovskis@gmail.com                                       10
#
#    Quiz: Python Mainīgie - Quiz (Real)  \
# 7                                   10
# 13                                  10
# 16                                  10
# ...

# %%
gr3.to_excel("gr3.xlsx")

# %%
ge2 = list(d2.email)
ge2
# Out:
# ['agris.aurmanis@gmail.com',
#  'job.andris@gmail.com',
#  'Austris.birkans@gmail.com',
#  'daniels_broks@inbox.lv',
#  'vitauts@klints.com',
#  'alyona.cimbalyuk@gmail.com',
#  'pavels.derjagins@gmail.com',
#  'frs.janis@gmail.com',
#  'krisjanisg@gmail.com',
#  'ieva.hermane@s1vsk.lv',
#  'Kristina_katrechko@inbox.lv',
#  'andris.kramzaks@gmail.com',
#  'raimonds.krauklis@gmail.com',
#  'j.kviesis@gmail.com',
#  'lazdovskis.davis@gmail.com',
#  'esperanse15@inbox.lv',
#  'edgars.android@gmail.com',
#  'rishardelux2@gmail.com',
#  'jekaterina.a@inbox.lv',
#  'arnis.rozentals@gmail.com',
#  'kalvis.salins@gmail.com',
#  'emsprogis@gmail.com',
#  'maris.staltmanis@tele2.com',
#  'dianast@inbox.lv',
#  'hidra4@inbox.lv',
#  'daira.toma@gmail.com',
#  'zv@tcp.lv',
#  'andris_ziemelis@inbox.lv',
#  'Sandis_zvejnieks@inbox.lv',
#  'martins.zviedris@gmail.com']

# %%
gr14 = d[d.email.isin(ge2)]
gr14.shape
# Out:
# (30, 25)

# %%
gr14.head()
# Out:
#    First name   Surname  ID number Institution  Department  \
# 12      AGRIS  AURMANIS        NaN         NaN         NaN
# 23     ANDRIS   BĒRZIŅŠ        NaN         NaN         NaN
# 26    Austris   Birkāns        NaN         NaN         NaN
# 34    DANIELS     BROKS        NaN         NaN         NaN
# 35    VITAUTS  BUDREIKA        NaN         NaN         NaN
#
#                         email Quiz: Ievads Programmēšanā - Quiz (Real)  \
# 12   agris.aurmanis@gmail.com                                       10
# 23       job.andris@gmail.com                                       10
# 26  Austris.birkans@gmail.com                                       10
# 34     daniels_broks@inbox.lv                                        8
# 35         vitauts@klints.com                                       10
#
#    Quiz: Python Mainīgie - Quiz (Real)  \
# 12                                  10
# 23                                  10
# 26                                  10
# ...

# %%
gr14.to_excel("gr-14.xlsx")
