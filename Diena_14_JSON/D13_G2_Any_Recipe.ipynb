# %%
 
import requests
import json
import pandas as pd
import time
url = "http://www.recipepuppy.com/api/?q=ingr"
 
def get_json_results(url):
    response = requests.get(url)
    if response.status_code != 200:
        return []
    return response.json().get('results')  
 
def get_single_page(url, to_excel = False):
    df = pd.DataFrame(get_json_results(url))
    df = df[['title', 'ingredients']]
#     df.head()  
#     df.tail()
    if to_excel:
        df.to_excel(f"{ingr}.xlsx")
    return df

def main(ingr):
    dfs = []
    for p in range(1,11):
        url = f"http://www.recipepuppy.com/api/?q={ingr}&p={p}"
        print(f"Retrieving: {url}")
        time.sleep(0.9)
        df = get_single_page(url)
        dfs.append(df)
        
    df = pd.concat(dfs)
    return df

# %%
ingr = input('Write down one ingredient like potato, selery, onions etc...:  ')
df = main(ingr)
df
# Out:
# Write down one ingredient like potato, selery, onions etc...:  onion
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=1
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=2
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=3
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=4
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=5
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=6
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=7
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=8
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=9
# Retrieving: http://www.recipepuppy.com/api/?q=onion&p=10
#                                                 title  \
# 0   Indian Restaurant Style Onion Bhaji - Deep Fri...
# 1                           Black and Tan Onion Rings
# 2                                  Onion Saute Recipe
# 3   Bubba Don't Eat This Onion Soup With Melted Mo...
# 4                   Sour Cream N Onion Burgers Recipe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        100 non-null    object
#  1   ingredients  100 non-null    object
# dtypes: object(2)
# memory usage: 2.3+ KB

# %%
df.to_csv("onions.csv")
