# %%
import pandas
url = "https://data.gov.lv/dati/dataset/633b5005-fe7f-44bd-b17c-4995d359f9b0/resource/975fb5a2-1be4-4183-b404-b32afe60c01a/download/kopa_cesu_pils_apmekletaju_veidi_pa_gadiem_menesiem.csv"
df = pandas.read_csv(url, sep=";")
df.head()
 
d2019 = df[df.Gads == 2019]
 
d2019
d2019.plot(kind="bar", x="Mēnesis")
d2019.plot(x="Mēnesis")
d2019.plot(kind="bar", x="Mēnesis", y=["Ārzemnieku grupa","Latvijas grupa"])
