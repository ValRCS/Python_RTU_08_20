# %% [markdown]
# # Documentation
# * Bulltet list
# * another bullet
#
# ![Python](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/520px-Python_logo_and_wordmark.svg.png)
#
# ![MyGraph](simplegraph.png)

# %%
import pandas as pd
# Pandas - excel on steroids..
# https://pandas.pydata.org/

# %%
df = pd.read_csv("../data/kopa_cesu_pils_apmekletaju_veidi_pa_gadiem_menesiem.csv")
df.head()
# Out:
#   Mēnesis;Ārzemnieku grupa;Latvijas grupa;Ģimene;Pāris;Viens;Draugi;Skolēnu grupa;Gads
# 0            Janvāris;492;110;576;385;9;322;189;2014
# 1              Februāris;69;94;90;94;15;145;196;2014
# 2               Marts;238;348;257;154;22;348;18;2014
# 3            Aprīlis;332;254;517;258;41;295;185;2014
# 4            Maijs;1257;2295;972;673;81;594;355;2014

# %%
df = pd.read_csv("../data/kopa_cesu_pils_apmekletaju_veidi_pa_gadiem_menesiem.csv", sep=";")
df.head()
# Out:
#      Mēnesis  Ārzemnieku grupa  Latvijas grupa  Ģimene  Pāris  Viens  Draugi  \
# 0   Janvāris               492             110     576    385      9     322
# 1  Februāris                69              94      90     94     15     145
# 2      Marts               238             348     257    154     22     348
# 3    Aprīlis               332             254     517    258     41     295
# 4      Maijs              1257            2295     972    673     81     594
#
#    Skolēnu grupa  Gads
# 0            189  2014
# 1            196  2014
# 2             18  2014
# 3            185  2014
# 4            355  2014

# %%
d2015 = df[df.Gads == 2015]
# d2015b = df[df['Gads'] == 2015] # this is safer in case our column names 
# conflict with method names
d2015
# Out:
#        Mēnesis  Ārzemnieku grupa  Latvijas grupa  Ģimene  Pāris  Viens  \
# 12    Janvāris               224              33     436    262     40
# 13   Februāris               269              89     190    172     30
# 14       Marts               118              43     490    228     26
# 15     Aprīlis               497             250     475    252     52
# 16       Maijs              1316             769    1080    778     97
# 17      Jūnijs              1870             765    1515   1232    132
# 18      Jūlijs              1780             477    4111   2057    216
# 19     Augusts              1896             197    2840   2107    174
# 20  Septembris              1521             417    1267   1073    111
# 21    Oktobris               849             623    1468    832     66
# 22   Novembris               367             167     519    284     22
# 23   Decembris               116             112     361    210     19
#
#     Draugi  Skolēnu grupa  Gads
# 12     170             53  2015
# 13     248            218  2015
# 14     190            187  2015
# 15     293            336  2015
# 16     515           2398  2015
# 17     696            225  2015
# 18    1738            126  2015
# 19    1208             36  2015
# 20     739           2045  2015
# 21     639           1490  2015
# 22     300            489  2015
# 23     116             87  2015

# %%
d2015.plot(x="Mēnesis")

# %%
#
df.to_excel("../data/cesis.xlsx") # we can save the results

# %%
foreigners = list(df["Ārzemnieku grupa"]) # for large not recommended
foreigners[:5]
# Out:
# [492, 69, 238, 332, 1257]

# %%
df.plot(use_index=True, y="Ārzemnieku grupa")

# %%
df.plot(x="Mēnesis", y="Ārzemnieku grupa")

# %%
months = list(df["Mēnesis"])
months[:5]
# Out:
# ['Janvāris', 'Februāris', 'Marts', 'Aprīlis', 'Maijs']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(months, foreigners)
plt.show() # it looks it grouped by months
