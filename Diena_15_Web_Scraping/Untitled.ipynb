# %%
# Requests for handling HTTP get and other requests
import requests
import time # import for playing nice and not getting blocked
import pandas as pd
# from BeautifulSoup4 import BeatifulSoup if installed through pip install BeautifulSoup4
# 
from bs4 import BeautifulSoup

# %%
url = "https://results.fmjd.org/tournaments/2020/f_696/tournament_table_acc_places.html"

# %%
df = pd.read_html(url, encoding="utf-8")
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 124

# %%
df[1].head()
# Out:
#    Vieta  Photo Tituls                                     Vārds, uzvārds  \
# 0      1    NaN    NaN  ALink("cardf_z$1.html", "Marija Magdal&#x0113;...
# 1      2    NaN    MFF  ALink("cardf_z$11.html", "Antra Valnere", fals...
# 2      3    NaN    NaN  ALink("cardf_z$3.html", "Jelizaveta Zaharova",...
# 3      4    NaN    NaN  ALink("cardf_z$10.html", "Valda,Vasariete", fa...
# 4      5    NaN    MFF  ALink("cardf_z$2.html", "Zoja Uva&#x010d;ana",...
#
#      FMJD                                                 R1  \
# 0  A 2004  ALink("cardf_z$10.html", "4b", false, "", " ti...
# 1  A 2113  ALink("cardf_z$8.html", "6w", false, "", " tit...
# 2  A 1933                                                 +0
# 3  A 1945  ALink("cardf_z$1.html", "1w", false, "", " tit...
# 4  A 1973  ALink("cardf_z$0.html", "10b", false, "", " ti...
#
#                                                   R2  \
# 0  ALink("cardf_z$0.html", "10w", false, "", " ti...
# 1  ALink("cardf_z$3.html", "3b", false, "", " tit...
# 2  ALink("cardf_z$11.html", "2w", false, "", " ti...
# 3  ALink("cardf_z$8.html", "6b", false, "", " tit...
# 4  ALink("cardf_z$5.html", "8w", false, "", " tit...
#
#                                                   R3  \
# 0  ALink("cardf_z$5.html", "8b", false, "", " tit...
# 1                                                 +0
# 2  ALink("cardf_z$10.html", "4b", false, "", " ti...
# 3  ALink("cardf_z$3.html", "3w", false, "", " tit...
# 4  ALink("cardf_z$12.html", "11b", false, "", " t...
#
#                                                   R4  \
# 0  ALink("cardf_z$12.html", "11w", false, "", " t...
# 1  ALink("cardf_z$10.html", "4w", false, "", " ti...
# 2  ALink("cardf_z$0.html", "10w", false, "", " ti...
# 3  ALink("cardf_z$11.html", "2b", false, "", " ti...
# 4  ALink("cardf_z$6.html", "9w", false, "", " tit...
#
#                                                   R5  \
# 0  ALink("cardf_z$6.html", "9b", false, "", " tit...
# 1  ALink("cardf_z$0.html", "10b", false, "", " ti...
# 2  ALink("cardf_z$5.html", "8b", false, "", " tit...
# 3                                                 +0
# 4  ALink("cardf_z$4.html", "7b", false, "", " tit...
#
#                                                   R6  \
# 0  ALink("cardf_z$4.html", "7w", false, "", " tit...
# 1  ALink("cardf_z$5.html", "8w", false, "", " tit...
# 2  ALink("cardf_z$12.html", "11w", false, "", " t...
# 3  ALink("cardf_z$0.html", "10w", false, "", " ti...
# 4                                                 +0
#
#                                                   R7  \
# 0  ALink("cardf_z$2.html", "5b", false, "", " tit...
# 1  ALink("cardf_z$12.html", "11b", false, "", " t...
# 2  ALink("cardf_z$6.html", "9b", false, "", " tit...
# 3  ALink("cardf_z$5.html", "8b", false, "", " tit...
# 4  ALink("cardf_z$1.html", "1w", false, "", " tit...
#
#                                                   R8  \
# 0                                                 +0
# 1  ALink("cardf_z$6.html", "9w", false, "", " tit...
# 2  ALink("cardf_z$4.html", "7w", false, "", " tit...
# 3  ALink("cardf_z$12.html", "11w", false, "", " t...
# 4  ALink("cardf_z$8.html", "6b", false, "", " tit...
#
#                                                   R9  \
# 0  ALink("cardf_z$8.html", "6w", false, "", " tit...
# 1  ALink("cardf_z$4.html", "7b", false, "", " tit...
# 2  ALink("cardf_z$2.html", "5b", false, "", " tit...
# 3  ALink("cardf_z$6.html", "9b", false, "", " tit...
# 4  ALink("cardf_z$3.html", "3w", false, "", " tit...
#
#                                                  R10  \
# 0  ALink("cardf_z$3.html", "3b", false, "", " tit...
# 1  ALink("cardf_z$2.html", "5w", false, "", " tit...
# 2  ALink("cardf_z$1.html", "1w", false, "", " tit...
# 3  ALink("cardf_z$4.html", "7w", false, "", " tit...
# 4  ALink("cardf_z$11.html", "2b", false, "", " ti...
#
#                                                  R11  Kopā  Uzvaras
# 0  ALink("cardf_z$11.html", "2w", false, "", " ti...    16        7
# 1  ALink("cardf_z$1.html", "1b", false, "", " tit...    16        7
# 2  ALink("cardf_z$8.html", "6b", false, "", " tit...    15        6
# 3  ALink("cardf_z$2.html", "5b", false, "", " tit...    14        6
# 4  ALink("cardf_z$10.html", "4w", false, "", " ti...    14        6

# %%
df[3].head()
# Out:
#                                                    0  1
# 0  ALink("cardf_z$0.html", "10w", false, "", " ti...  2

# %%
df[1].describe()
# Out:
#            Vieta  Photo      Kopā    Uzvaras
# count  11.000000    0.0  11.00000  11.000000
# mean    6.000000    NaN  10.00000   4.181818
# std     3.316625    NaN   5.07937   2.315953
# min     1.000000    NaN   3.00000   1.000000
# 25%     3.500000    NaN   6.00000   2.500000
# 50%     6.000000    NaN   9.00000   4.000000
# 75%     8.500000    NaN  14.50000   6.000000
# max    11.000000    NaN  16.00000   7.000000

# %%
df[1].describe(include='all')
# Out:
#             Vieta  Photo Tituls  \
# count   11.000000    0.0      2
# unique        NaN    NaN      1
# top           NaN    NaN    MFF
# freq          NaN    NaN      2
# mean     6.000000    NaN    NaN
# std      3.316625    NaN    NaN
# min      1.000000    NaN    NaN
# 25%      3.500000    NaN    NaN
# 50%      6.000000    NaN    NaN
# 75%      8.500000    NaN    NaN
# max     11.000000    NaN    NaN
#
#                                            Vārds, uzvārds    FMJD  \
# count                                                  11      10
# unique                                                 11      10
# top     ALink("cardf_z$11.html", "Antra Valnere", fals...  B 1799
# freq                                                    1       1
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                                                        R1  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$5.html", "8b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R2  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$1.html", "1b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R3  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$5.html", "8b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R4  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$1.html", "1b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R5  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$5.html", "8b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R6  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$1.html", "1b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R7  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$5.html", "8b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R8  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$0.html", "10b", false, "", " ti...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                        R9  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$1.html", "1b", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       R10  \
# count                                                  11
# unique                                                 11
# top     ALink("cardf_z$1.html", "1w", false, "", " tit...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                       R11      Kopā    Uzvaras
# count                                                  11  11.00000  11.000000
# unique                                                 11       NaN        NaN
# top     ALink("cardf_z$1.html", "1b", false, "", " tit...       NaN        NaN
# freq                                                    1       NaN        NaN
# mean                                                  NaN  10.00000   4.181818
# std                                                   NaN   5.07937   2.315953
# min                                                   NaN   3.00000   1.000000
# 25%                                                   NaN   6.00000   2.500000
# 50%                                                   NaN   9.00000   4.000000
# 75%                                                   NaN  14.50000   6.000000
# max                                                   NaN  16.00000   7.000000

# %%
df[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Vieta           11 non-null     int64
#  1   Photo           0 non-null      float64
#  2   Tituls          2 non-null      object
#  3   Vārds, uzvārds  11 non-null     object
#  4   FMJD            10 non-null     object
#  5   R1              11 non-null     object
#  6   R2              11 non-null     object
#  7   R3              11 non-null     object
#  8   R4              11 non-null     object
#  9   R5              11 non-null     object
#  10  R6              11 non-null     object
#  11  R7              11 non-null     object
#  12  R8              11 non-null     object
#  13  R9              11 non-null     object
#  14  R10             11 non-null     object
#  15  R11             11 non-null     object
#  16  Kopā            11 non-null     int64
#  17  Uzvaras         11 non-null     int64
# dtypes: float64(1), int64(3), object(14)
# memory usage: 1.7+ KB
