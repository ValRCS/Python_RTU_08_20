# %%
# !pip install selenium # only once!
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\liga\anaconda3\lib\site-packages (from selenium) (1.25.9)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# now drivers

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome() # so you need driver for the browser

# %%
browser.get('http://www.ss.com')
assert 'SS' in browser.title

# %%
# elem = browser.find_element_by_name('p')  # Find the search box
# elem.send_keys('seleniumhq' + Keys.RETURN)

# %%
browser.current_url
# Out:
# 'https://www.ss.com/'

# %%
cars =browser.find_element_by_id("mtd_97")
type(cars)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
cars.get_attribute('href')
# Out:
# 'https://www.ss.com/lv/transport/cars/'

# %%
cars.get_attribute('title')
# Out:
# 'Vieglie auto'

# %%
cars.text
# Out:
# 'Vieglie auto'

# %%
# https://devhints.io/xpath
apart = browser.find_element_by_xpath('//a[@title="Dzīvokļi"]') # XPath is very powerful tool for finding elements

# %%
apart.click() # i can emulate a mouse click

# %%
browser.back()

# %%
browser.forward()

# %%
riga = browser.find_element_by_xpath('//a[@title="Rīga, Sludinājumi"]')
type(riga)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
riga.click()

# %%
browser.current_url
# Out:
# 'https://www.ss.com/lv/real-estate/flats/riga/'

# %%
browser.get_window_size()
# Out:
# {'width': 974, 'height': 1047}

# %%
# save with Pillow graphibrowser.get_screenshot_as_png()

browser.save_screenshot("page.png")
# Out:
# True

# %%
myel = browser.find_element_by_id('ahc_1089')

# %%
myel.text
# Out:
# 'Bolderāja'

# %%
myel.get_property('attributes')
# Out:
# [{'ATTRIBUTE_NODE': 2,
#   'CDATA_SECTION_NODE': 4,
#   'COMMENT_NODE': 8,
#   'DOCUMENT_FRAGMENT_NODE': 11,
#   'DOCUMENT_NODE': 9,
#   'DOCUMENT_POSITION_CONTAINED_BY': 16,
#   'DOCUMENT_POSITION_CONTAINS': 8,
#   'DOCUMENT_POSITION_DISCONNECTED': 1,
#   'DOCUMENT_POSITION_FOLLOWING': 4,
#   'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#   'DOCUMENT_POSITION_PRECEDING': 2,
#   'DOCUMENT_TYPE_NODE': 10,
#   'ELEMENT_NODE': 1,
#   'ENTITY_NODE': 6,
#   'ENTITY_REFERENCE_NODE': 5,
#   'NOTATION_NODE': 12,
#   'PROCESSING_INSTRUCTION_NODE': 7,
#   'TEXT_NODE': 3,
#   'addEventListener': {},
#   'appendChild': {},
#   'baseURI': 'https://www.ss.com/',
#   'childNodes': [],
#   'cloneNode': {},
#   'compareDocumentPosition': {},
#   'contains': {},
#   'dispatchEvent': {},
#   'firstChild': None,
#   'getRootNode': {},
#   'hasChildNodes': {},
#   'insertBefore': {},
#   'isConnected': False,
#   'isDefaultNamespace': {},
#   'isEqualNode': {},
#   'isSameNode': {},
#   'lastChild': None,
#   'localName': 'id',
#   'lookupNamespaceURI': {},
#   'lookupPrefix': {},
#   'name': 'id',
#   'namespaceURI': None,
#   'nextSibling': None,
#   'nodeName': 'id',
#   'nodeType': 2,
#   'nodeValue': 'ahc_1089',
#   'normalize': {},
#   'ownerDocument': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="76720bb4-10a8-4d2d-9ae0-bd465702df79")>,
#   'ownerElement': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="132d7a9f-5a61-4acc-b045-97b4d667e93d")>,
#   'parentElement': None,
#   'parentNode': None,
#   'prefix': None,
#   'previousSibling': None,
#   'removeChild': {},
#   'removeEventListener': {},
#   'replaceChild': {},
#   'specified': True,
#   'textContent': 'ahc_1089',
#   'value': 'ahc_1089'},
#  {'ATTRIBUTE_NODE': 2,
#   'CDATA_SECTION_NODE': 4,
#   'COMMENT_NODE': 8,
#   'DOCUMENT_FRAGMENT_NODE': 11,
#   'DOCUMENT_NODE': 9,
#   'DOCUMENT_POSITION_CONTAINED_BY': 16,
#   'DOCUMENT_POSITION_CONTAINS': 8,
#   'DOCUMENT_POSITION_DISCONNECTED': 1,
#   'DOCUMENT_POSITION_FOLLOWING': 4,
#   'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#   'DOCUMENT_POSITION_PRECEDING': 2,
#   'DOCUMENT_TYPE_NODE': 10,
#   'ELEMENT_NODE': 1,
#   'ENTITY_NODE': 6,
#   'ENTITY_REFERENCE_NODE': 5,
#   'NOTATION_NODE': 12,
#   'PROCESSING_INSTRUCTION_NODE': 7,
#   'TEXT_NODE': 3,
#   'addEventListener': {},
#   'appendChild': {},
#   'baseURI': 'https://www.ss.com/',
#   'childNodes': [],
#   'cloneNode': {},
#   'compareDocumentPosition': {},
#   'contains': {},
#   'dispatchEvent': {},
#   'firstChild': None,
#   'getRootNode': {},
#   'hasChildNodes': {},
#   'insertBefore': {},
#   'isConnected': False,
#   'isDefaultNamespace': {},
#   'isEqualNode': {},
#   'isSameNode': {},
#   'lastChild': None,
#   'localName': 'href',
#   'lookupNamespaceURI': {},
#   'lookupPrefix': {},
#   'name': 'href',
#   'namespaceURI': None,
#   'nextSibling': None,
#   'nodeName': 'href',
#   'nodeType': 2,
#   'nodeValue': '/lv/real-estate/flats/riga/bolderaya/',
#   'normalize': {},
#   'ownerDocument': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="76720bb4-10a8-4d2d-9ae0-bd465702df79")>,
#   'ownerElement': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="132d7a9f-5a61-4acc-b045-97b4d667e93d")>,
#   'parentElement': None,
#   'parentNode': None,
#   'prefix': None,
#   'previousSibling': None,
#   'removeChild': {},
#   'removeEventListener': {},
#   'replaceChild': {},
#   'specified': True,
#   'textContent': '/lv/real-estate/flats/riga/bolderaya/',
#   'value': '/lv/real-estate/flats/riga/bolderaya/'},
#  {'ATTRIBUTE_NODE': 2,
#   'CDATA_SECTION_NODE': 4,
#   'COMMENT_NODE': 8,
#   'DOCUMENT_FRAGMENT_NODE': 11,
#   'DOCUMENT_NODE': 9,
#   'DOCUMENT_POSITION_CONTAINED_BY': 16,
#   'DOCUMENT_POSITION_CONTAINS': 8,
#   'DOCUMENT_POSITION_DISCONNECTED': 1,
#   'DOCUMENT_POSITION_FOLLOWING': 4,
#   'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#   'DOCUMENT_POSITION_PRECEDING': 2,
#   'DOCUMENT_TYPE_NODE': 10,
#   'ELEMENT_NODE': 1,
#   'ENTITY_NODE': 6,
#   'ENTITY_REFERENCE_NODE': 5,
#   'NOTATION_NODE': 12,
#   'PROCESSING_INSTRUCTION_NODE': 7,
#   'TEXT_NODE': 3,
#   'addEventListener': {},
#   'appendChild': {},
#   'baseURI': 'https://www.ss.com/',
#   'childNodes': [],
#   'cloneNode': {},
#   'compareDocumentPosition': {},
#   'contains': {},
#   'dispatchEvent': {},
#   'firstChild': None,
#   'getRootNode': {},
#   'hasChildNodes': {},
#   'insertBefore': {},
#   'isConnected': False,
#   'isDefaultNamespace': {},
#   'isEqualNode': {},
#   'isSameNode': {},
#   'lastChild': None,
#   'localName': 'class',
#   'lookupNamespaceURI': {},
#   'lookupPrefix': {},
#   'name': 'class',
#   'namespaceURI': None,
#   'nextSibling': None,
#   'nodeName': 'class',
#   'nodeType': 2,
#   'nodeValue': 'a_category',
#   'normalize': {},
#   'ownerDocument': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="76720bb4-10a8-4d2d-9ae0-bd465702df79")>,
#   'ownerElement': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="132d7a9f-5a61-4acc-b045-97b4d667e93d")>,
#   'parentElement': None,
#   'parentNode': None,
#   'prefix': None,
#   'previousSibling': None,
#   'removeChild': {},
#   'removeEventListener': {},
#   'replaceChild': {},
#   'specified': True,
#   'textContent': 'a_category',
#   'value': 'a_category'},
#  {'ATTRIBUTE_NODE': 2,
#   'CDATA_SECTION_NODE': 4,
#   'COMMENT_NODE': 8,
#   'DOCUMENT_FRAGMENT_NODE': 11,
#   'DOCUMENT_NODE': 9,
#   'DOCUMENT_POSITION_CONTAINED_BY': 16,
#   'DOCUMENT_POSITION_CONTAINS': 8,
#   'DOCUMENT_POSITION_DISCONNECTED': 1,
#   'DOCUMENT_POSITION_FOLLOWING': 4,
#   'DOCUMENT_POSITION_IMPLEMENTATION_SPECIFIC': 32,
#   'DOCUMENT_POSITION_PRECEDING': 2,
#   'DOCUMENT_TYPE_NODE': 10,
#   'ELEMENT_NODE': 1,
#   'ENTITY_NODE': 6,
#   'ENTITY_REFERENCE_NODE': 5,
#   'NOTATION_NODE': 12,
#   'PROCESSING_INSTRUCTION_NODE': 7,
#   'TEXT_NODE': 3,
#   'addEventListener': {},
#   'appendChild': {},
#   'baseURI': 'https://www.ss.com/',
#   'childNodes': [],
#   'cloneNode': {},
#   'compareDocumentPosition': {},
#   'contains': {},
#   'dispatchEvent': {},
#   'firstChild': None,
#   'getRootNode': {},
#   'hasChildNodes': {},
#   'insertBefore': {},
#   'isConnected': False,
#   'isDefaultNamespace': {},
#   'isEqualNode': {},
#   'isSameNode': {},
#   'lastChild': None,
#   'localName': 'title',
#   'lookupNamespaceURI': {},
#   'lookupPrefix': {},
#   'name': 'title',
#   'namespaceURI': None,
#   'nextSibling': None,
#   'nodeName': 'title',
#   'nodeType': 2,
#   'nodeValue': 'Bolderāja, Sludinājumi',
#   'normalize': {},
#   'ownerDocument': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="76720bb4-10a8-4d2d-9ae0-bd465702df79")>,
#   'ownerElement': <selenium.webdriver.remote.webelement.WebElement (session="b80d7e51b9c071e52fc17af8c88e350e", element="132d7a9f-5a61-4acc-b045-97b4d667e93d")>,
#   'parentElement': None,
#   'parentNode': None,
#   'prefix': None,
#   'previousSibling': None,
#   'removeChild': {},
#   'removeEventListener': {},
#   'replaceChild': {},
#   'specified': True,
#   'textContent': 'Bolderāja, Sludinājumi',
#   'value': 'Bolderāja, Sludinājumi'}]

# %%
myel.click()
